# %%
import requests
import pandas as pd
import difflib
from bs4 import BeautifulSoup
import re
import fuzzywuzzy
from thefuzz import process
from thefuzz import fuzz

# %%
def get_categories(url) -> 'List': 
    ''' 
    Params: str: Board game url (ex: https://boardgamegeek.com/xmlapi/boardgame/{gameID})

    Returns: List: List of categories 
    '''
    response = requests.get(url)
    soup = BeautifulSoup(response.text)

    cat_text = soup.find_all('boardgamecategory')
    cat_list = []
    for cats in cat_text:
        s = str(cats)

        # extract important text between <stuff> important text </stuff>
        c = re.sub(r'<[^>]+>', '', s)
        cat_list.append(c)

    return(cat_list)

# %%
testUrl = 'https://boardgamegeek.com/xmlapi/boardgame/13'

print(get_categories(testUrl))
# Out:
# ['Economic', 'Negotiation']

# %% [markdown]
# ### Getting all the categories from BGG

# %%
categories_url = 'https://boardgamegeek.com/browse/boardgamecategory'

categories_response = requests.get(categories_url)

# print(response.text)

category_soup = BeautifulSoup(categories_response.text)
# print(soup.find_all('a'))

categories = []
for link in category_soup.find_all('a'):
    cat_string = link.get('href')
    if cat_string != None:
        categories.append(cat_string.split('/')[-1])
        
## the categories are, luckily, alphabetized
# print(categories)

# %% [markdown]
# ### Merging bgg and shelfside data on name
# ID might be better to be honest

# %%
bgg_full_gamelist = pd.read_csv('bgg_gamelist.csv')
shelfside_gamelist = pd.read_csv('Shelfside Games Reviewed - Review Data.csv')

## Renaming Game to name for compatibility
shelfside_gamelist = shelfside_gamelist.rename(columns = {'Game':'name'})

## need to drop rows either Ash or Dan hasn't given a rating
relevant_metrics = ['name', 'score', 'dan score', 'ash score']
data = shelfside_gamelist[relevant_metrics]
data_cleaned = data.dropna(subset = relevant_metrics)
# data_cleaned

## getting the urls for every game in the bgg_gamelist
game_ids = bgg_full_gamelist['id'].to_list()
game_urls = [f'https://boardgamegeek.com/xmlapi/boardgame/{x}' for x in game_ids]
bgg_full_gamelist['game_urls'] = game_urls
bgg_full_gamelist
# Out:
#          id                                             name   nrate  \
# 0        13                                            CATAN  128958
# 1       822                                      Carcassonne  128106
# 2     30549                                         Pandemic  126448
# 3     68448                                        7 Wonders  105376
# 4    167791                                Terraforming Mars  100322
# ..      ...                                              ...     ...
# 995  105593                                    Cheating Moth    5088
# 996    2386                                 Chinese Checkers    5078
# 997  244995                                         Illusion    5071
# 998  226522  Exit: The Game – Dead Man on the Orient Express    5069
# 999  343905                                         Boonlake    5069
#
#                                                pic_url  \
# 0    https://cf.geekdo-images.com/W3Bsga_uLP9kO91gZ...
# 1    https://cf.geekdo-images.com/okM0dq_bEXnbyQTOv...
# 2    https://cf.geekdo-images.com/S3ybV1LAp-8SnHIXL...
# 3    https://cf.geekdo-images.com/35h9Za_JvMMMtx_92...
# 4    https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZ...
# ..                                                 ...
# 995  https://cf.geekdo-images.com/7w7ht4bmAnu0j-_qg...
# 996  https://cf.geekdo-images.com/MFhxbJJRHjIb4oWn7...
# 997  https://cf.geekdo-images.com/jcFaI9hr6iXwpwCZT...
# 998  https://cf.geekdo-images.com/atCG4ujYJ-L5LKID3...
# 999  https://cf.geekdo-images.com/xRcKQXVz-mDxz-32J...
#
#                                              game_urls
# 0        https://boardgamegeek.com/xmlapi/boardgame/13
# 1       https://boardgamegeek.com/xmlapi/boardgame/822
# 2     https://boardgamegeek.com/xmlapi/boardgame/30549
# 3     https://boardgamegeek.com/xmlapi/boardgame/68448
# 4    https://boardgamegeek.com/xmlapi/boardgame/167791
# ..                                                 ...
# 995  https://boardgamegeek.com/xmlapi/boardgame/105593
# 996    https://boardgamegeek.com/xmlapi/boardgame/2386
# 997  https://boardgamegeek.com/xmlapi/boardgame/244995
# 998  https://boardgamegeek.com/xmlapi/boardgame/226522
# 999  https://boardgamegeek.com/xmlapi/boardgame/343905
#
# [1000 rows x 5 columns]

# %%
# Creating a dataframe
dict_one = {
  "country": ["England", "Scotland", "Wales", "United Kingdom", "Northern Ireland"],
  "population_in_millions": [55.98, 5.45, 3.14, 67.33, 1.89]
}

dict_two = {
  "country": ["Northern Iland", "Wles", "Scotlnd", "Englnd", "United K."],
  "GDP_per_capita": [24900, 23882, 37460, 45101, 46510.28]
}

existing_data = pd.DataFrame(dict_one)
exported_data = pd.DataFrame(dict_two)
print(existing_data, exported_data, sep="\n\n")
# Out:
#             country  population_in_millions
# 0           England                   55.98
# 1          Scotland                    5.45
# 2             Wales                    3.14
# 3    United Kingdom                   67.33
# 4  Northern Ireland                    1.89
#
#           country  GDP_per_capita
# 0  Northern Iland        24900.00
# 1            Wles        23882.00
# 2         Scotlnd        37460.00
# 3          Englnd        45101.00
# 4       United K.        46510.28

# %%
# # Rename the misspelled columns
# exported_data["country"] = exported_data["country"].apply(
#   lambda x: process.extractOne(x, existing_data["country"], scorer=fuzz.partial_ratio)[0]
# )
# # Attempt to join the two dataframe
# data = pd.merge(existing_data, exported_data, on="country", how="left")
# print(data.head())

# %%
# Rename the misspelled columns
# bgg_full_gamelist['name'] = bgg_full_gamelist['name'].apply(
#   lambda x: process.extractOne(x, data_cleaned['name'], scorer=fuzz.partial_ratio)[0]
# )
# # Attempt to join the two dataframe
# merged_df = data_cleaned.join(bgg_full_gamelist.set_index('name'), on='name')
# # print(merged_df.head())
# merged_df

# %%
data_cleaned
# Out:
#                      name  score  dan score  ash score
# 0                Dominion    8.0        4.0        7.0
# 1         The Resistance     9.0        5.0        6.0
# 2              Incan Gold    7.0        8.0        8.0
# 3                Splendor    9.0        7.0        6.0
# 4                   Dixit    6.0        8.0        4.0
# ..                    ...    ...        ...        ...
# 116              Bohnanza    7.0        6.0        7.0
# 120  Twilight Inscription    5.0        3.0        6.0
# 139               Acquire    9.0        6.0        7.0
# 140                 Earth   10.0        6.0        6.0
# 144           Bloodstones    6.0        5.0        4.0
#
# [70 rows x 4 columns]

# %%
def matching(list_in, list_compare):

    for i in range(len(list_in)):
        print(f'\nShelfname: {list_in[i]}')
        # score_list = process.extractWithoutOrder(list_in[i], list_compare, scorer = fuzz.partial_ratio, score_cutoff=81)
        score_list = process.extractWithoutOrder(list_in[i], list_compare, scorer = fuzz.ratio, score_cutoff=70)
        print(list(score_list))

        # for item in score_list:

# %%
shelf_names = data_cleaned['name'].to_list()
bgg_names = bgg_full_gamelist['name'].to_list()

matching(shelf_names, bgg_names)
# Out:
# Shelfname: Dominion
# [('Dominion', 100), ('Dominoes', 75)]
#
# Shelfname: The Resistance
# [('The Resistance', 100), ('The Resistance: Avalon', 78)]
#
# Shelfname: Incan Gold
# [('Incan Gold', 100)]
#
# Shelfname: Splendor
# [('Splendor', 100), ('Splendor Duel', 76)]
#
# Shelfname: Dixit
# [('Dixit', 100)]
#
# Shelfname: Coup
# [('Coup', 100)]
#
# Shelfname: SanGuoSha
# []
#
# Shelfname: Suburbia
# [('Suburbia', 100)]
#
# Shelfname: Cash N Guns
# [("Ca$h 'n Gun$", 82)]
#
# Shelfname: Monikers
# [('Monikers', 100)]
#
# Shelfname: Taboo
# [('Taboo', 100)]
#
# Shelfname: Once Upon a Time
# []
#
# Shelfname: Archer Love Letter
# [('Love Letter', 76), ('Love Letter', 76)]
#
# Shelfname: Codenames
# [('Codenames', 100), ('Codenames: Duet', 75)]
#
# Shelfname: Pandemic
# [('Pandemic', 100)]
#
# Shelfname: Sheriff of Nottingham
# [('Sheriff of Nottingham', 100)]
#
# Shelfname: Last Word
# []
#
# Shelfname: Bears vs. Babies
# []
#
# Shelfname: King of Tokyo
# [('King of Tokyo', 100), ('King of Tokyo: Power Up!', 72)]
#
# Shelfname: Smash Up
# [('Smash Up', 100)]
#
# Shelfname: Say Anything
# [('Say Anything', 100)]
#
# Shelfname: Cutthroat Caverns
# []
#
# Shelfname: Bloodborne
# [('Blood Rage', 70)]
#
# Shelfname: Eldritch Horror
# [('Eldritch Horror', 100)]
#
# Shelfname: How to Rob a Bank
# []
#
# Shelfname: Pictomania
# [('Pictionary', 70)]
#
# Shelfname: Dune
# [('Dune', 100), ('Dune', 100)]
#
# Shelfname: Wingspan
# [('Wingspan', 100), ('Wingspan Asia', 76)]
#
# Shelfname: Throw Throw Burrito
# []
#
# Shelfname: Root
# [('Root', 100), ('Loot', 75)]
#
# Shelfname: Mansions of Madness
# [('Mansions of Madness: Second Edition', 70), ('Mansions of Madness', 100)]
#
# Shelfname: Takenoko
# [('Takenoko', 100)]
#
# Shelfname: Betrayal at House on the Hill
# [('Betrayal at House on the Hill', 100)]
#
# Shelfname: Food Chain Magnate
# [('Food Chain Magnate', 100)]
#
# Shelfname: Gloomhaven: Jaws of the Lion
# [('Gloomhaven: Jaws of the Lion', 100)]
#
# Shelfname: Hellapagos
# []
#
# Shelfname: TI4
# []
#
# Shelfname: Deep Sea Adventure
# [('Deep Sea Adventure', 100)]
#
# Shelfname: Tellstones: King's Gambit
# []
#
# Shelfname: Detective: Season One
# [('Dice Throne: Season One', 73)]
#
# Shelfname: Chinatown
# [('Chinatown', 100)]
#
# Shelfname: Dominion 2nd Edition
# [('Dominion (Second Edition)', 86), ('London (Second Edition)', 71)]
#
# Shelfname: Dead of Winter
# []
#
# Shelfname: Tainted Grail
# []
#
# Shelfname: Oath
# [('Oath', 100)]
#
# Shelfname: Unfathomable
# [('Unfathomable', 100)]
#
# Shelfname: Dune: A Game of Conquest and Diplomacy
# []
#
# Shelfname: Dune Imperium
# [('Dune: Imperium', 96)]
#
# Shelfname: Fast and Furious: Highway Heist
# []
#
# Shelfname: Legacy's Allure
# []
#
# Shelfname: Scythe
# [('Scythe', 100)]
#
# Shelfname: Gloomhaven
# [('Gloomhaven', 100)]
#
# Shelfname: Sid Meier's Civilization: The Board Game (2010)
# [("Sid Meier's Civilization: The Board Game", 93)]
#
# Shelfname: Dune Imperium — Rise of Ix
# [('Dune: Imperium – Rise of Ix', 98), ('Dune: Imperium – Uprising', 78)]
#
# Shelfname: Civilization: A New Dawn
# [('Civilization: A New Dawn', 100)]
#
# Shelfname: All Time Wrestling
# []
#
# Shelfname: Radlands
# [('Radlands', 100)]
#
# Shelfname: Lost Ruins of Arnak
# [('Lost Ruins of Arnak', 100)]
#
# Shelfname: Galactic Era
# []
#
# Shelfname: Blitz Bowl: Ultimate Edition
# [('Mage Knight: Ultimate Edition', 70), ('Blood Bowl (Third Edition)', 72)]
#
# Shelfname: Mammothodus
# []
#
# Shelfname: Tainted Grail: Kings of Ruin
# []
#
# Shelfname: Horizons of Spirit Island
# []
#
# Shelfname: Rising Sun
# [('Rising Sun', 100)]
#
# Shelfname: Re;Act
# []
#
# Shelfname: Bohnanza
# [('Bohnanza', 100)]
#
# Shelfname: Twilight Inscription
# []
#
# Shelfname: Acquire
# [('Acquire', 100)]
#
# Shelfname: Earth
# [('Earth', 100), ('Unearth', 83)]
#
# Shelfname: Bloodstones
# []

# %%
# data_cleaned['name'] = data_cleaned['name'].apply(
#   lambda x: process.extractOne(x, bgg_full_gamelist['name'], scorer=fuzz.partial_ratio, score_cutoff=80)[0]
# )
# data_cleaned

# %%
# df0 = pd.Dataframe

## super slow for loop but gotta see em: 
# for x in game_urls:
#     print(x)
#     print(get_categories(x))

# %%
## map goes like map(func, iterable) -- takes forever too but more than a thousand games
# result = map(get_categories, game_urls)
# list(result)

# %%
# def fuzzy_match(row, choices, scorer=fuzz.partial_ratio, threshold=80):
#     match = process.extractOne(row['name'], choices, scorer=scorer)
#     # Only return match if score is above a certain threshold, else return None
#     if match and match[1] >= threshold:
#         return match[0]
#     else:
#         return None

# # Apply fuzzy matching and create a new column for the matched name
# bgg_full_gamelist['fuzzy_name'] = bgg_full_gamelist.apply(
#     lambda row: fuzzy_match(row, data_cleaned['name']), axis=1
# )

# # Merge the dataframes based on the fuzzy matched name
# merged_df = pd.merge(
#     data_cleaned, 
#     bgg_full_gamelist, 
#     left_on='name', 
#     right_on='fuzzy_name', 
#     how="left"
# )
