# %% [markdown]
# # Selenium Scraping
# This notebook currently takes the data from the csv Ashton gave me and will use webscraping to access BGG's data and metrics of a particular boardgame

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import difflib
import pandas as pd

# %%
bgg_full_gamelist = pd.read_csv('bgg_gamelist.csv')
shelfside_gamelist = pd.read_csv('Shelfside Games Reviewed - Review Data.csv')

## Renaming Game to name for compatibility
shelfside_gamelist = shelfside_gamelist.rename(columns = {'Game':'name'})

# %% [markdown]
# ## Merging Dan and Ash's review scores with the data from BGG

# %%
## want a case-insensitive merge so sending names to be lowercase 
shelfside_gamelist['name_lower'] = shelfside_gamelist['name'].str.lower()
bgg_full_gamelist['name_lower'] = bgg_full_gamelist['name'].str.lower()

shelfside_cleaned = shelfside_gamelist.dropna(subset = ['score', 'dan score', 'ash score'])
shelfside_cleaned
# # shelfside_gamelist.head()
# new = pd.merge(shelfside_gamelist, bgg_full_gamelist, on = 'name_lower')
# new
# Out:
#                      name Published   score  dan score  ash score  \
# 0                Dominion        yes    8.0        4.0        7.0
# 1         The Resistance         yes    9.0        5.0        6.0
# 2              Incan Gold        yes    7.0        8.0        8.0
# 3                Splendor        Yes    9.0        7.0        6.0
# 4                   Dixit        Yes    6.0        8.0        4.0
# ..                    ...        ...    ...        ...        ...
# 116              Bohnanza        Yes    7.0        6.0        7.0
# 120  Twilight Inscription        Yes    5.0        3.0        6.0
# 139               Acquire        Yes    9.0        6.0        7.0
# 140                 Earth        Yes   10.0        6.0        6.0
# 144           Bloodstones        Yes    6.0        5.0        4.0
#
#      date publish video length  \
# 0     Jul 12 2019        16:46
# 1    July 13 2019         8:16
# 2    July 14 2019         7:40
# 3    July 15 2019        17:13
# 4    July 25 2019        16:01
# ..            ...          ...
# 116      20230204          NaN
# 120      20230317          NaN
# 139      20240124          NaN
# 140      20240130          NaN
# 144      20240319          NaN
#
#                                               Vid Link How to Play Vid?  \
# 0    https://www.youtube.com/watch?v=XqQwYKayNZw&pp...                N
# 1                         https://youtu.be/fRIF0aMdllI                N
# 2                         https://youtu.be/HCKQDo3iQEE                N
# 3                         https://youtu.be/RnOPUOzytDg                N
# 4                         https://youtu.be/sCTJ2Tnm9XY                N
# ..                                                 ...              ...
# 116                       https://youtu.be/hVXjX0NYHbU              NaN
# 120                       https://youtu.be/BTYsn5SKsUA              NaN
# 139                       https://youtu.be/G4xLaC23FVo              NaN
# 140                       https://youtu.be/hSIUbJ2NOe0              NaN
# 144                       https://youtu.be/faopOuoPQak              NaN
#
#     How to Play Length Notes            name_lower
# 0                  NaN   NaN              dominion
# 1                  NaN   NaN       the resistance
# 2                  NaN   NaN            incan gold
# 3                  NaN   NaN              splendor
# 4                  NaN   NaN                 dixit
# ..                 ...   ...                   ...
# 116                NaN   NaN              bohnanza
# 120                NaN   NaN  twilight inscription
# 139                NaN   NaN               acquire
# 140                NaN   NaN                 earth
# 144                NaN   NaN           bloodstones
#
# [70 rows x 12 columns]

# %%
shelfside_gamelist
# Out:
#                                      name Published   score  dan score  \
# 0                                Dominion        yes    8.0        4.0
# 1                         The Resistance         yes    9.0        5.0
# 2                              Incan Gold        yes    7.0        8.0
# 3                                Splendor        Yes    9.0        7.0
# 4                                   Dixit        Yes    6.0        8.0
# ..                                    ...        ...    ...        ...
# 148              Mythic Battles: Ragnorok        Yes    7.0        NaN
# 149  All Time Wrestling: Abu Dhabi Rumble         No    NaN        NaN
# 150                           Deliverance        Yes    6.0        7.0
# 151                       Brink Prototype        Yes    6.0        NaN
# 152                   Degenesis Prototype        Yes    4.0        NaN
#
#      ash score  date publish video length  \
# 0          7.0   Jul 12 2019        16:46
# 1          6.0  July 13 2019         8:16
# 2          8.0  July 14 2019         7:40
# 3          6.0  July 15 2019        17:13
# 4          4.0  July 25 2019        16:01
# ..         ...           ...          ...
# 148        5.0      20240611          NaN
# 149        7.0           NaN          NaN
# 150        NaN      20240620          NaN
# 151        6.0      20240702          NaN
# 152        6.0      20240731          NaN
#
#                                               Vid Link How to Play Vid?  \
# 0    https://www.youtube.com/watch?v=XqQwYKayNZw&pp...                N
# 1                         https://youtu.be/fRIF0aMdllI                N
# 2                         https://youtu.be/HCKQDo3iQEE                N
# 3                         https://youtu.be/RnOPUOzytDg                N
# 4                         https://youtu.be/sCTJ2Tnm9XY                N
# ..                                                 ...              ...
# 148                       https://youtu.be/HXk_z4SBWHg              NaN
# 149                                                NaN              NaN
# 150                       https://youtu.be/Bz4NrpmUaIE              NaN
# 151                       https://youtu.be/H9qN9ra4cOg              NaN
# 152                       https://youtu.be/atl3S_yCjH4              NaN
#
#     How to Play Length Notes                            name_lower
# 0                  NaN   NaN                              dominion
# 1                  NaN   NaN                       the resistance
# 2                  NaN   NaN                            incan gold
# 3                  NaN   NaN                              splendor
# 4                  NaN   NaN                                 dixit
# ..                 ...   ...                                   ...
# 148                NaN   NaN              mythic battles: ragnorok
# 149                NaN   NaN  all time wrestling: abu dhabi rumble
# 150                NaN   NaN                           deliverance
# 151                NaN   NaN                       brink prototype
# 152                NaN   NaN                   degenesis prototype
#
# [153 rows x 12 columns]

# %%
# df_merged = pd.merge(df_address, 
#                      df_CountryMapping, 
#                      left_on=df_address["Country"].str.lower(), 
#                      right_on=df_CountryMapping["NAME"].str.lower(), 
#                      how="left")
df1 = pd.DataFrame([[1,'one'],[2,'two'],[3,'three'],[4,'four'],[5,'five']], columns=['number', 'name'])
df2 = pd.DataFrame([['a','one'],['b','too'],['c','three'],['d','fours'],['e','five']], columns=['letter', 'name'])

df2['name'] = df2['name'].apply(lambda x: difflib.get_close_matches(x, df1['name'])[0])
df1.merge(df2)
# Out:
#    number   name letter
# 0       1    one      a
# 1       2    two      b
# 2       3  three      c
# 3       4   four      d
# 4       5   five      e

# %%
service = Service(executable_path=r'/usr/bin/chromedriver')
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(service=service, options=options)

## webscraping from webpage output -- most likely slower
# driver.get('https://boardgamegeek.com/boardgame/417542/')
# print('classification' in driver.page_source)
# game_metrics = driver.find_element(By.CLASS_NAME, 'panel-body')
# print(game_metrics.text)
# print('---------------------')
# game_categories = driver.find_element(By.CLASS_NAME, 'text-block')
# print(game_categories.text)


## xml api approach -- most likely faster
driver.get('https://boardgamegeek.com/xmlapi/boardgame/417542')
# print(driver.page_source)

driver.quit()
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml"><head><style id="xml-viewer-style">/* Copyright 2014 The Chromium Authors
#  * Use of this source code is governed by a BSD-style license that can be
#  * found in the LICENSE file.
#  */
#
# :root {
#   color-scheme: light dark;
# }
#
# div.header {
#     border-bottom: 2px solid black;
#     padding-bottom: 5px;
#     margin: 10px;
# }
#
# @media (prefers-color-scheme: dark) {
#   div.header {
#     border-bottom: 2px solid white;
#   }
# }
#
# div.folder &gt; div.hidden {
#     display:none;
# }
#
# div.folder &gt; span.hidden {
#     display:none;
# }
#
# .pretty-print {
#     margin-top: 1em;
#     margin-left: 20px;
#     font-family: monospace;
#     font-size: 13px;
# }
#
# #webkit-xml-viewer-source-xml {
#     display: none;
# }
#
# .opened {
#     margin-left: 1em;
# }
#
# .comment {
#     white-space: pre;
# }
#
# .folder-button {
#     user-select: none;
#     cursor: pointer;
#     display: inline-block;
#     margin-left: -10px;
#     width: 10px;
#     background-repeat: no-repeat;
#     background-position: left top;
#     vertical-align: bottom;
# }
#
# .fold {
#     background: url("data:image/svg+xml,&lt;svg xmlns='http://www.w3.org/2000/svg' fill='%23909090' width='10' height='10'&gt;&lt;path d='M0 0 L8 0 L4 7 Z'/&gt;&lt;/svg&gt;");
#     height: 10px;
# }
#
# .open {
#     background: url("data:image/svg+xml,&lt;svg xmlns='http://www.w3.org/2000/svg' fill='%23909090' width='10' height='10'&gt;&lt;path d='M0 0 L0 8 L7 4 Z'/&gt;&lt;/svg&gt;");
#     height: 10px;
# }
# </style></head><body><div id="webkit-xml-viewer-source-xml"><boardgames xmlns="" termsofuse="https://boardgamegeek.com/xmlapi/termsofuse">
# 			<boardgame objectid="417542">
#    <yearpublished>2025</yearpublished>
#    <minplayers>1</minplayers>
#    <maxplayers>4</maxplayers>
#    <playingtime>90</playingtime>
#    <minplaytime>60</minplaytime>
#    <maxplaytime>90</maxplaytime>
#    <age>14</age>
#
#    	   <name primary="true" sortindex="1">Cyberpunk 2077: The Board Game</name>
#
#    <description>Cyberpunk 2077: the Board Game is a fast-paced cooperative tactical card game, for Welcome to Night City, the metropolis of the future. Here, the local blends with the global, and the past,&lt;br/&gt;present, and future merge into one.&lt;br/&gt;&lt;br/&gt;1-4 players, where each Player controls one Character &amp;ndash; an Edgerunner. With the guidance of the App and the Locations Map, Players will decide which Mission to take. Through a series of real-time Fights and Cooldowns between them, Players must complete the Main Objectives provided by the Mission card&amp;rsquo;s description. Each Character has a deck with Action cards and unique features specific to them.&lt;br/&gt;&lt;br/&gt;The main part of the game will happen in Sequential Timed Action Phase Fight segments, managed by the App. After the signal, Players look at their hands, choose an Active Player, and play their turns one after the other, starting with the Active Player, until the time runs out.&lt;br/&gt;&lt;br/&gt;Then Players will go through the Steps of the Cooldown Phase, discard all cards from their hands, check loot, and prepare for the next STAP. Players may take as much time as they need to update the game state, gear up, and discuss their further actions and strategy.&lt;br/&gt;&lt;br/&gt;All Players win the game together if they successfully manage to complete all Main Objectives for the Mission. Players lose the game if they fail to complete any Main Objective in time. The Objective requirement will specify what the Players need to do to meet them. Immediately after the Active Player completes it, they receive the shown reward.&lt;br/&gt;&lt;br/&gt;&amp;lsquo;It's a blitz through the underbelly of this city, where you fight,&lt;br/&gt;hack, and hustle your way to the top. Just like the good old days.&amp;rsquo;&lt;br/&gt;&lt;br/&gt;</description>
#
#    	   <thumbnail>https://cf.geekdo-images.com/m3EyNhiDH41DMKnprrPO8Q__thumb/img/Y9SE8H81ovyqAn6D9SLQlQ69FJw=/fit-in/200x150/filters:strip_icc()/pic8376768.png</thumbnail>
# 	   https://cf.geekdo-images.com/m3EyNhiDH41DMKnprrPO8Q__original/img/n23q8_LK7LjTVQPXF1_X_nGgO68=/0x0/filters:format(png)/pic8376768.png
#
#    	   		   <boardgamepublisher objectid="7297">CD Projekt RED</boardgamepublisher>
#       	   		   <boardgamepublisher objectid="37558">Go On Board</boardgamepublisher>
#       	   		   <boardgamepodcastepisode objectid="530407">129 Devon Dice News Show Podcast, plus crowdfunding and played games</boardgamepodcastepisode>
#       	   		   <boardgamefamily objectid="22783">Admin: Better Description Needed!</boardgamefamily>
#       	   		   <boardgamefamily objectid="22184">Admin: Upcoming Releases</boardgamefamily>
#       	   		   <boardgamecategory objectid="1022">Adventure</boardgamecategory>
#       	   		   <cardset objectid="106056">CD Projekt RED/Go On Board deluxe edition (2025)</cardset>
#       	   		   <cardset objectid="106055">CD Projekt RED/Go On Board standard edition (2025)</cardset>
#       	   		   <boardgamefamily objectid="66292">Crowdfunding: Gamefound</boardgamefamily>
#       	   		   <cardset objectid="106058">Cyberpunk 2077: The Board Game – Johnny Silverhand &amp; NCPD Expansion</cardset>
#       	   		   <cardset objectid="106059">Cyberpunk 2077: The Board Game – Johnny Silverhand Expansion</cardset>
#       	   		   <boardgamecategory objectid="1017">Dice</boardgamecategory>
#       	   		   <boardgamewriter objectid="142028">Barnaba Drukała</boardgamewriter>
#       	   		   <boardgameversion objectid="707364">English edition</boardgameversion>
#       	   		   <boardgameversion objectid="707431">French edition</boardgameversion>
#       	   		   <boardgameversion objectid="707432">German edition</boardgameversion>
#       	   		   <boardgameversion objectid="707433">Italian edition</boardgameversion>
#       	   		   <boardgamedeveloper objectid="141835">Przemysław Kot-Rembowski</boardgamedeveloper>
#       	   		   <boardgamedeveloper objectid="132061">Artur Lutyński</boardgamedeveloper>
#       	   		   <boardgamecategory objectid="1047">Miniatures</boardgamecategory>
#       	   		   <boardgamedeveloper objectid="160161">Eryk Nowak</boardgamedeveloper>
#       	   		   <boardgamedeveloper objectid="138124">Franciszek Ostojski</boardgamedeveloper>
#       	   		   <boardgameversion objectid="707429">Polish edition</boardgameversion>
#       	   		   <boardgamecategory objectid="1016">Science Fiction</boardgamecategory>
#       	   		   <boardgameversion objectid="707430">Spanish edition</boardgameversion>
#       	   		   <boardgamedeveloper objectid="160160">Michał Sprysak</boardgamedeveloper>
#       	   		   <boardgamedeveloper objectid="81635">Łukasz Szopka</boardgamedeveloper>
#       	   		   <boardgamefamily objectid="5611">Theme: Cyberpunk</boardgamefamily>
#       	   		   <boardgamecategory objectid="1101">Video Game Theme</boardgamecategory>
#       	   		   <boardgamedeveloper objectid="130965">Wojciech Wiśniewski</boardgamedeveloper>
#       	   		   <boardgameeditor objectid="152207">Jarosław Wójcicki</boardgameeditor>
#       	   		   <boardgamedesigner objectid="51428">Łukasz Woźniak</boardgamedesigner>
#
#    <poll name="suggested_numplayers" title="User Suggested Number of Players" totalvotes="0">
#
# 		<results numplayers="1">
# 					<result value="Best" numvotes="0"/>
# 					<result value="Recommended" numvotes="0"/>
# 					<result value="Not Recommended" numvotes="0"/>
# 				</results>
#
# 		<results numplayers="2">
# 					<result value="Best" numvotes="0"/>
# 					<result value="Recommended" numvotes="0"/>
# 					<result value="Not Recommended" numvotes="0"/>
# 				</results>
#
# 		<results numplayers="3">
# 					<result value="Best" numvotes="0"/>
# 					<result value="Recommended" numvotes="0"/>
# 					<result value="Not Recommended" numvotes="0"/>
# 				</results>
#
# 		<results numplayers="4">
# 					<result value="Best" numvotes="0"/>
# 					<result value="Recommended" numvotes="0"/>
# 					<result value="Not Recommended" numvotes="0"/>
# 				</results>
#
# 		<results numplayers="4+">
# 					<result value="Best" numvotes="0"/>
# 					<result value="Recommended" numvotes="0"/>
# 					<result value="Not Recommended" numvotes="0"/>
# 				</results>
# 	</poll>
#
#    <poll name="language_dependence" title="Language Dependence" totalvotes="0">
#
# 		<results>
# 					<result level="1" value="No necessary in-game text" numvotes="0"/>
# 					<result level="2" value="Some necessary text - easily memorized or small crib sheet" numvotes="0"/>
# 					<result level="3" value="Moderate in-game text - needs crib sheet or paste ups" numvotes="0"/>
# 					<result level="4" value="Extensive use of text - massive conversion needed to be playable" numvotes="0"/>
# 					<result level="5" value="Unplayable in another language" numvotes="0"/>
# 				</results>
# 	</poll>
#
#    <poll name="suggested_playerage" title="User Suggested Player Age" totalvotes="0">
# 			<results>
# 					<result value="2" numvotes="0"/>
# 					<result value="3" numvotes="0"/>
# 					<result value="4" numvotes="0"/>
# 					<result value="5" numvotes="0"/>
# 					<result value="6" numvotes="0"/>
# 					<result value="8" numvotes="0"/>
# 					<result value="10" numvotes="0"/>
# 					<result value="12" numvotes="0"/>
# 					<result value="14" numvotes="0"/>
# 					<result value="16" numvotes="0"/>
# 					<result value="18" numvotes="0"/>
# 					<result value="21 and up" numvotes="0"/>
# 				</results>
# 	</poll>
#
#
#
#
#
#
# </boardgame>
#
# </boardgames></div><div class="header"><span>This XML file does not appear to have any style information associated with it. The document tree is shown below.</span><br /></div><div class="pretty-print"><div class="folder" id="folder0"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;boardgames<span class="html-attribute"> <span class="html-attribute-name">termsofuse</span>="<span class="html-attribute-value">https://boardgamegeek.com/xmlapi/termsofuse</span>"</span>&gt;</span></div><div class="opened"><span>
# 			</span><div class="folder" id="folder1"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;boardgame<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">417542</span>"</span>&gt;</span></div><div class="opened"><span>
#    </span><div class="line"><span class="html-tag">&lt;yearpublished&gt;</span><span>2025</span><span class="html-tag">&lt;/yearpublished&gt;</span></div><span>
#    </span><div class="line"><span class="html-tag">&lt;minplayers&gt;</span><span>1</span><span class="html-tag">&lt;/minplayers&gt;</span></div><span>
#    </span><div class="line"><span class="html-tag">&lt;maxplayers&gt;</span><span>4</span><span class="html-tag">&lt;/maxplayers&gt;</span></div><span>
#    </span><div class="line"><span class="html-tag">&lt;playingtime&gt;</span><span>90</span><span class="html-tag">&lt;/playingtime&gt;</span></div><span>
#    </span><div class="line"><span class="html-tag">&lt;minplaytime&gt;</span><span>60</span><span class="html-tag">&lt;/minplaytime&gt;</span></div><span>
#    </span><div class="line"><span class="html-tag">&lt;maxplaytime&gt;</span><span>90</span><span class="html-tag">&lt;/maxplaytime&gt;</span></div><span>
#    </span><div class="line"><span class="html-tag">&lt;age&gt;</span><span>14</span><span class="html-tag">&lt;/age&gt;</span></div><span>
#
#    	   </span><div class="line"><span class="html-tag">&lt;name<span class="html-attribute"> <span class="html-attribute-name">primary</span>="<span class="html-attribute-value">true</span>"</span><span class="html-attribute"> <span class="html-attribute-name">sortindex</span>="<span class="html-attribute-value">1</span>"</span>&gt;</span><span>Cyberpunk 2077: The Board Game</span><span class="html-tag">&lt;/name&gt;</span></div><span>
#
#    </span><div class="line"><span class="html-tag">&lt;description&gt;</span><span>Cyberpunk 2077: the Board Game is a fast-paced cooperative tactical card game, for Welcome to Night City, the metropolis of the future. Here, the local blends with the global, and the past,&lt;br/&gt;present, and future merge into one.&lt;br/&gt;&lt;br/&gt;1-4 players, where each Player controls one Character &amp;ndash; an Edgerunner. With the guidance of the App and the Locations Map, Players will decide which Mission to take. Through a series of real-time Fights and Cooldowns between them, Players must complete the Main Objectives provided by the Mission card&amp;rsquo;s description. Each Character has a deck with Action cards and unique features specific to them.&lt;br/&gt;&lt;br/&gt;The main part of the game will happen in Sequential Timed Action Phase Fight segments, managed by the App. After the signal, Players look at their hands, choose an Active Player, and play their turns one after the other, starting with the Active Player, until the time runs out.&lt;br/&gt;&lt;br/&gt;Then Players will go through the Steps of the Cooldown Phase, discard all cards from their hands, check loot, and prepare for the next STAP. Players may take as much time as they need to update the game state, gear up, and discuss their further actions and strategy.&lt;br/&gt;&lt;br/&gt;All Players win the game together if they successfully manage to complete all Main Objectives for the Mission. Players lose the game if they fail to complete any Main Objective in time. The Objective requirement will specify what the Players need to do to meet them. Immediately after the Active Player completes it, they receive the shown reward.&lt;br/&gt;&lt;br/&gt;&amp;lsquo;It's a blitz through the underbelly of this city, where you fight,&lt;br/&gt;hack, and hustle your way to the top. Just like the good old days.&amp;rsquo;&lt;br/&gt;&lt;br/&gt;</span><span class="html-tag">&lt;/description&gt;</span></div><span>
#
#    	   </span><div class="line"><span class="html-tag">&lt;thumbnail&gt;</span><span>https://cf.geekdo-images.com/m3EyNhiDH41DMKnprrPO8Q__thumb/img/Y9SE8H81ovyqAn6D9SLQlQ69FJw=/fit-in/200x150/filters:strip_icc()/pic8376768.png</span><span class="html-tag">&lt;/thumbnail&gt;</span></div><span>
# 	   </span><div class="line"><span class="html-tag">&lt;image&gt;</span><span>https://cf.geekdo-images.com/m3EyNhiDH41DMKnprrPO8Q__original/img/n23q8_LK7LjTVQPXF1_X_nGgO68=/0x0/filters:format(png)/pic8376768.png</span><span class="html-tag">&lt;/image&gt;</span></div><span>
#
#    	   		   </span><div class="line"><span class="html-tag">&lt;boardgamepublisher<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">7297</span>"</span>&gt;</span><span>CD Projekt RED</span><span class="html-tag">&lt;/boardgamepublisher&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamepublisher<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">37558</span>"</span>&gt;</span><span>Go On Board</span><span class="html-tag">&lt;/boardgamepublisher&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamepodcastepisode<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">530407</span>"</span>&gt;</span><span>129 Devon Dice News Show Podcast, plus crowdfunding and played games</span><span class="html-tag">&lt;/boardgamepodcastepisode&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamefamily<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">22783</span>"</span>&gt;</span><span>Admin: Better Description Needed!</span><span class="html-tag">&lt;/boardgamefamily&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamefamily<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">22184</span>"</span>&gt;</span><span>Admin: Upcoming Releases</span><span class="html-tag">&lt;/boardgamefamily&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamecategory<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">1022</span>"</span>&gt;</span><span>Adventure</span><span class="html-tag">&lt;/boardgamecategory&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;cardset<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">106056</span>"</span>&gt;</span><span>CD Projekt RED/Go On Board deluxe edition (2025)</span><span class="html-tag">&lt;/cardset&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;cardset<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">106055</span>"</span>&gt;</span><span>CD Projekt RED/Go On Board standard edition (2025)</span><span class="html-tag">&lt;/cardset&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamefamily<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">66292</span>"</span>&gt;</span><span>Crowdfunding: Gamefound</span><span class="html-tag">&lt;/boardgamefamily&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;cardset<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">106058</span>"</span>&gt;</span><span>Cyberpunk 2077: The Board Game – Johnny Silverhand &amp; NCPD Expansion</span><span class="html-tag">&lt;/cardset&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;cardset<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">106059</span>"</span>&gt;</span><span>Cyberpunk 2077: The Board Game – Johnny Silverhand Expansion</span><span class="html-tag">&lt;/cardset&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamecategory<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">1017</span>"</span>&gt;</span><span>Dice</span><span class="html-tag">&lt;/boardgamecategory&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamewriter<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">142028</span>"</span>&gt;</span><span>Barnaba Drukała</span><span class="html-tag">&lt;/boardgamewriter&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgameversion<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">707364</span>"</span>&gt;</span><span>English edition</span><span class="html-tag">&lt;/boardgameversion&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgameversion<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">707431</span>"</span>&gt;</span><span>French edition</span><span class="html-tag">&lt;/boardgameversion&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgameversion<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">707432</span>"</span>&gt;</span><span>German edition</span><span class="html-tag">&lt;/boardgameversion&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgameversion<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">707433</span>"</span>&gt;</span><span>Italian edition</span><span class="html-tag">&lt;/boardgameversion&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamedeveloper<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">141835</span>"</span>&gt;</span><span>Przemysław Kot-Rembowski</span><span class="html-tag">&lt;/boardgamedeveloper&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamedeveloper<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">132061</span>"</span>&gt;</span><span>Artur Lutyński</span><span class="html-tag">&lt;/boardgamedeveloper&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamecategory<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">1047</span>"</span>&gt;</span><span>Miniatures</span><span class="html-tag">&lt;/boardgamecategory&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamedeveloper<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">160161</span>"</span>&gt;</span><span>Eryk Nowak</span><span class="html-tag">&lt;/boardgamedeveloper&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamedeveloper<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">138124</span>"</span>&gt;</span><span>Franciszek Ostojski</span><span class="html-tag">&lt;/boardgamedeveloper&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgameversion<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">707429</span>"</span>&gt;</span><span>Polish edition</span><span class="html-tag">&lt;/boardgameversion&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamecategory<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">1016</span>"</span>&gt;</span><span>Science Fiction</span><span class="html-tag">&lt;/boardgamecategory&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgameversion<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">707430</span>"</span>&gt;</span><span>Spanish edition</span><span class="html-tag">&lt;/boardgameversion&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamedeveloper<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">160160</span>"</span>&gt;</span><span>Michał Sprysak</span><span class="html-tag">&lt;/boardgamedeveloper&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamedeveloper<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">81635</span>"</span>&gt;</span><span>Łukasz Szopka</span><span class="html-tag">&lt;/boardgamedeveloper&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamefamily<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">5611</span>"</span>&gt;</span><span>Theme: Cyberpunk</span><span class="html-tag">&lt;/boardgamefamily&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamecategory<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">1101</span>"</span>&gt;</span><span>Video Game Theme</span><span class="html-tag">&lt;/boardgamecategory&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamedeveloper<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">130965</span>"</span>&gt;</span><span>Wojciech Wiśniewski</span><span class="html-tag">&lt;/boardgamedeveloper&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgameeditor<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">152207</span>"</span>&gt;</span><span>Jarosław Wójcicki</span><span class="html-tag">&lt;/boardgameeditor&gt;</span></div><span>
#       	   		   </span><div class="line"><span class="html-tag">&lt;boardgamedesigner<span class="html-attribute"> <span class="html-attribute-name">objectid</span>="<span class="html-attribute-value">51428</span>"</span>&gt;</span><span>Łukasz Woźniak</span><span class="html-tag">&lt;/boardgamedesigner&gt;</span></div><span>
#
#    </span><div class="folder" id="folder2"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;poll<span class="html-attribute"> <span class="html-attribute-name">name</span>="<span class="html-attribute-value">suggested_numplayers</span>"</span><span class="html-attribute"> <span class="html-attribute-name">title</span>="<span class="html-attribute-value">User Suggested Number of Players</span>"</span><span class="html-attribute"> <span class="html-attribute-name">totalvotes</span>="<span class="html-attribute-value">0</span>"</span>&gt;</span></div><div class="opened"><span>
#
# 		</span><div class="folder" id="folder3"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;results<span class="html-attribute"> <span class="html-attribute-name">numplayers</span>="<span class="html-attribute-value">1</span>"</span>&gt;</span></div><div class="opened"><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Best</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Not Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 				</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/results&gt;</span></div></div><span>
#
# 		</span><div class="folder" id="folder4"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;results<span class="html-attribute"> <span class="html-attribute-name">numplayers</span>="<span class="html-attribute-value">2</span>"</span>&gt;</span></div><div class="opened"><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Best</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Not Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 				</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/results&gt;</span></div></div><span>
#
# 		</span><div class="folder" id="folder5"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;results<span class="html-attribute"> <span class="html-attribute-name">numplayers</span>="<span class="html-attribute-value">3</span>"</span>&gt;</span></div><div class="opened"><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Best</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Not Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 				</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/results&gt;</span></div></div><span>
#
# 		</span><div class="folder" id="folder6"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;results<span class="html-attribute"> <span class="html-attribute-name">numplayers</span>="<span class="html-attribute-value">4</span>"</span>&gt;</span></div><div class="opened"><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Best</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Not Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 				</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/results&gt;</span></div></div><span>
#
# 		</span><div class="folder" id="folder7"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;results<span class="html-attribute"> <span class="html-attribute-name">numplayers</span>="<span class="html-attribute-value">4+</span>"</span>&gt;</span></div><div class="opened"><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Best</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Not Recommended</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 				</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/results&gt;</span></div></div><span>
# 	</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/poll&gt;</span></div></div><span>
#
#    </span><div class="folder" id="folder8"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;poll<span class="html-attribute"> <span class="html-attribute-name">name</span>="<span class="html-attribute-value">language_dependence</span>"</span><span class="html-attribute"> <span class="html-attribute-name">title</span>="<span class="html-attribute-value">Language Dependence</span>"</span><span class="html-attribute"> <span class="html-attribute-name">totalvotes</span>="<span class="html-attribute-value">0</span>"</span>&gt;</span></div><div class="opened"><span>
#
# 		</span><div class="folder" id="folder9"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;results&gt;</span></div><div class="opened"><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">level</span>="<span class="html-attribute-value">1</span>"</span><span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">No necessary in-game text</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">level</span>="<span class="html-attribute-value">2</span>"</span><span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Some necessary text - easily memorized or small crib sheet</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">level</span>="<span class="html-attribute-value">3</span>"</span><span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Moderate in-game text - needs crib sheet or paste ups</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">level</span>="<span class="html-attribute-value">4</span>"</span><span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Extensive use of text - massive conversion needed to be playable</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">level</span>="<span class="html-attribute-value">5</span>"</span><span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">Unplayable in another language</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 				</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/results&gt;</span></div></div><span>
# 	</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/poll&gt;</span></div></div><span>
#
#    </span><div class="folder" id="folder10"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;poll<span class="html-attribute"> <span class="html-attribute-name">name</span>="<span class="html-attribute-value">suggested_playerage</span>"</span><span class="html-attribute"> <span class="html-attribute-name">title</span>="<span class="html-attribute-value">User Suggested Player Age</span>"</span><span class="html-attribute"> <span class="html-attribute-name">totalvotes</span>="<span class="html-attribute-value">0</span>"</span>&gt;</span></div><div class="opened"><span>
# 			</span><div class="folder" id="folder11"><div class="line"><span class="folder-button fold"></span><span class="html-tag">&lt;results&gt;</span></div><div class="opened"><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">2</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">3</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">4</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">5</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">6</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">8</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">10</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">12</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">14</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">16</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">18</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 					</span><div class="line"><span class="html-tag">&lt;result<span class="html-attribute"> <span class="html-attribute-name">value</span>="<span class="html-attribute-value">21 and up</span>"</span><span class="html-attribute"> <span class="html-attribute-name">numvotes</span>="<span class="html-attribute-value">0</span>"</span>/&gt;</span></div><span>
# 				</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/results&gt;</span></div></div><span>
# 	</span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/poll&gt;</span></div></div><span>
#
#
#
#
#
#
# </span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/boardgame&gt;</span></div></div><span>
#
# </span></div><span class="folded hidden">...</span><div class="line"><span class="html-tag">&lt;/boardgames&gt;</span></div></div></div></body></html>

# %%
game_ids = bgg_full_gamelist['id'].to_list()
game_urls = [f'https://boardgamegeek.com/xmlapi/boardgame/{x}' for x in game_ids]
